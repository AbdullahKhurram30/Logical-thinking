# %% [markdown]
# # Formal Analyses Assignment 1
# ## Logical Thinking
# ### *Would you rather?*

# %% [markdown]
# ## Overview
#
# For this assignment, you will craft arguments in favor of each side of a “would you rather” question. You must then analyze the arguments in full, making strong applications of all of the logical thinking HCs. The arguments can be as simple or as sophisticated as you wish! Keep in mind that more complicated arguments will require a richer, more careful analysis. This may be a good way to showcase your knowledge, but could also lead to more flaws. Moreover, in pursuit of the appropriate difficulty level, you’ll notice several “Optional” problems throughout the assignment to challenge yourself. These will only be scored if they are completed correctly with thorough explanation. If you attempt an optional challenge but do not succeed, you will not be penalized with a low score.
#
# ## Formatting & HC Guidelines
#
# You must complete all tasks within this pre-formatted Jupyter notebook. **Please follow the formatting guidelines and the HC Guidelines in the assignment instructions on Forum (near the top and bottom of the instructions respectively).**

# %% [markdown]
# ## Would you rather?
#
# Please choose a question from [this spreadsheet](https://docs.google.com/spreadsheets/d/1Q-q1q7ofKpTSaP4kNQL_Fq7GGiHhJc9psxuq8usoIUM/edit?usp=sharing). There are two parts below, and in each part, you will argue a different side of the argument for your chosen question. For example, if your question was, “Would you rather code in Python or code in Java?”, you would focus on one side only in PART 1: “I would rather code in Python.” In PART 2, you would craft an inductive argument for the other side, “I would rather code in Java.” **Please review the guidelines and examples provided to help you write effective arguments in the assignment instructions on Forum.**

# %% [markdown]
# ## PART 1
# #### In this part, you will work with one side of the argument only. As explained above, if your question was, “Would you rather code in Python or code in Java?” then one side would be “I would rather code in Python.” For the chosen side of the argument, craft two brief arguments using deductive reasoning. One argument should be a valid deduction and one should contain a fallacy. Write these arguments in natural language in simple terms with clear use of logical connectives and atomic sentences so that it is amenable for the following analysis. [#deduction, #fallacies, #algorithms]

# %% [markdown]
# ### Write your question and your deductive arguments.

# %% [markdown]
# Would you rather have real political power but be relatively poor, or be ridiciously rich and have no political power?

# %% [markdown]
# If I am rich, then I will have lots of money.
# If I have lots of money, then I can buy anything I want.
# I can be happy or sad.
# I don't want to be sad.
# I want to be happy.
# If I have everything I want, I will be happy.
# If I have political power, then I will have resposibilities too.
# Having money does not mean resposibilities.
# Therefore, I would rather be rich and not have political power.

# %% [markdown]
# If I am rich, then I will have lots of money.
# If I have lots of money, then I can buy what I want.
# If I buy anything I want, I will be happy.
# If am happy
# I am successful
# Therefore, I would rather be rich rather than have political power.

# %% [markdown]
# ### 1. Clearly identify the features of these arguments that make them deductive and explain why (<75 words).

# %% [markdown]
# The argument is based on logic rules and not a matter of fact. The conclusion in within the scope of the premises and follows from them. It is based on logic rules and not evidence from observations. The argument is straightforward and relatable as well as being easy to follow instead of depending on predictions and analogies. The terminology used e.g. therefore, is also characteristic of a deductive argument. Thus, the argument is deductive.

# %% [markdown]
# ### 2. For the valid deduction:

# %% [markdown]
# #### 2.1 Translate your argument into symbolic logic.

# %% [markdown]
# Key:-
# P: I want to be rich
# Q: I want to have lots of money
# R: I can buy anything I want
# S: I am happy
# T: I am sad
# U: I want political power
# V: I want responsibilities
# Translation:-
# P1: P --> Q
# P2: Q --> R
# P3: S v T
# P4: ~T
# P5: S
# P6: R --> S
# P7: U --> V
# P8: ~V
# C:  P & ~U

# %% [markdown]
# #### 2.2 Choose two sentences from the argument and negate them using DeMorgan’s laws. Ideally, you should choose two sentences that have different logical connectives. Translate the negations back into English.

# %% [markdown]
# Key:-
# P: I want to be  rich
# Q: I want to have lots of money
# S: I am happy
# T: I am sad
# Premises:-
# P --> Q
# S v T
# Applying De Morgan's laws and negating:
# P & ~Q
# ~S & ~T
# Translation to natural language:
# I want to be rich, and not have lots of money
# I am not happy and I am not sad

# %% [markdown]
# #### 2.3 Prove that the argument is indeed valid using a formal proof.

# %% [markdown]
# 1. P --> Q      Premise
# 2. Q --> R      Premise
# 3. S v T        Premise
# 4. ~T           Premise
# 5. S            Premise
# 6. R --> S      Premise
# 7. U --> V      Premise
# 8. ~V           Premise
# 9.  |P          Assumption for conditional derivation
# 10. |Q          Modus-ponens 1,9
# 11. |R          Modus-ponens 2,10
# 12. P --> R     conditional derivation 9-11
# 13. ~T          Repeat 4
# 14. S           Modus-Tollendo-ponens 3,4
# 15. |P          Assumption for conditional derivation
# 16. |R          Modus-ponens 12,15
# 17. |S          Modus-ponens 6,16
# 18. P --> S     conditional derivation 15-17
# 19. ~V          Repeat 8
# 20. ~U          Modus-tollens 7,8
# 21. P & ~U      Conclusion
# 22. P           Simplification 21

# %% [markdown]
# #### 2.4 Discuss the soundness of the argument (<100 words).

# %% [markdown]
# A sound argument is one that is valid and all of it's premises are true. As all the premises are true and the argument has proven to be valid. A direct proof was used to prove that the argument is valid and comes to a conclusion that is true. Thus, the argument is sound.

# %% [markdown]
# #### 2.5 *Optional*: Negate each of the premises of your argument and derive a valid conclusion, being sure to explain the derivation and comment on the soundness. If it is impossible to form a valid argument from these premises, explain why.

# %% [markdown]
# Write your answer for 2.5 (*optional*) here (double click to edit the cell).

# %% [markdown]
# ### 3. Python
# #### 3.1 Use Python to assess the validity of the argument. The code should output whether or not the argument is valid (it should be valid!) based on a truth table. You are not required to print the full truth table, but it might provide you with a helpful sanity check. You may use a similar code from session 5 (3.1), simply adapting it to your argument, or if you wish, write your own from scratch. The code from lesson 4 (2.2) may also be helpful. Whatever approach you take, you must clearly explain how the code works (as described below).
#
# #### As with any code, you need to include clearly annotated in-line comments to document what the code is doing and how it is using logic. Read this [resource](https://mikegrouchy.com/blog/yes-your-code-does-need-comments) about the importance of comments and [this one](https://realpython.com/python-comments-guide/) for further guidance.
#
# #### In addition to your brief in-line comments, you must also include an overarching explanation of what the code is doing as a whole in connection with #deduction. In particular, you should explain how the truth table is used to ascertain validity and how this logic concept is incorporated in the code (<150 words).

# %%
# write your code for 3.1 here
#using code from session 3.1
def conditional(a, b):
    #inputs two variables 
    #gives boolean output for a --> b
    return not a or b
#defining the first premise
def premise1(p, q, r, s, t, u, v):
    #gives boolean output for p --> q
    return conditional(not p, not q)
#defining the second premise
def premise2(p, q, r, s, t, u, v):
    #gives boolean output for q --> r
    return conditional( not q, not r)
#defining the third premise
def premise3(p, q, r, s, t, u, v):
    #gives boolean output for s v t
    return s or t
#defining the fourth premise
def premise4(p, q, r, s, t, u, v):
    #gives boolean output for ~t
    return not t
#defining the fifth premise
def premise5(p, q, r, s, t, u, v):
    #gives boolean output for s
    return s
#defining the sixth premise
def premise6(p, q, r, s, t, u, v):
    #gives boolean output for r --> s
    return conditional(not r, not s)
#defining the seventh premise
def premise7(p, q, r, s, t, u, v):
    #gives boolean output for u --> v
    return conditional(not u, not v)
#defining the eight premise
def premise8(p, q, r, s, t, u, v):
    #gives boolean output for ~v
    return not v
#defining the conclusion
def conclusion(p, q, r, s, t, u, v):
    #gives boolean output for p & ~u
    return p and not u
#defining the function that checks validity
def valid_checker(P1, P2, P3, P4, P5, P6, P7, P8, concl):
    print('p\t, q\t, r\t, s\t, t\t,u\t, v\t, P1\t, P2\t, P3\t, P4\t, P5\t, P6\t, P7\t, P8\t, conclusion')
    validity = True # set variable value
    #setting up iteration
    for p in [True, False]:
        for q in [True, False]: 
            for r in [True, False]:
                for s in [True, False]:
                    for t in [True, False]:
                        for u in [True, False]:
                            for v in [True, False]:
                                #printing truth table
                                print(p,'\t',q,'\t',r,'\t',s,'\t',t,'\t',u,'\t',v,'\t',
                                P1(p, q, r, s, t, u, v),'\t',P2(p, q, r, s, t, u, v),'\t',P3(p, q, r, s, t, u, v),'\t',
                                P4(p, q, r, s, t, u, v),'\t',P5(p, q, r, s, t, u, v),'\t',P6(p, q, r, s, t, u, v),'\t',
                                P7(p, q, r, s, t, u, v),'\t',P8(p, q, r, s, t, u, v),'\t',concl(p, q, r, s, t, u, v))
                                #checking the validity
                                if P1(p, q, r, s, t, u, v) == True and P2(p, q, r, s, t, u, v) == True and P3(p, q, r, s, t, u, v) == True and P4(p, q, r, s, t, u, v) == True and P5(p, q, r, s, t, u, v) == True and P6(p, q, r, s, t, u, v) == True and P7(p, q, r, s, t, u, v) == True and P8(p, q, r, s, t, u, v) == True and conclusion(p, q, r, s, t, u, v) == False:
                                    validity == False #changing the variable value
                                    if validity == False:
                                        print("Argument is invalid")
                                        return
    print("Argument is valid")   
#calling the function
#takes boolean inputs from other functions
valid_checker(premise1, premise2, premise3, premise4, premise5, premise6, premise7, premise8, conclusion)
# Out:
# p	, q	, r	, s	, t	,u	, v	, P1	, P2	, P3	, P4	, P5	, P6	, P7	, P8	, conclusion
# True 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 False 	 True 	 True 	 True 	 False 	 False
# True 	 True 	 True 	 True 	 True 	 True 	 False 	 True 	 True 	 True 	 False 	 True 	 True 	 True 	 True 	 False
# True 	 True 	 True 	 True 	 True 	 False 	 True 	 True 	 True 	 True 	 False 	 True 	 True 	 False 	 False 	 True
# True 	 True 	 True 	 True 	 True 	 False 	 False 	 True 	 True 	 True 	 False 	 True 	 True 	 True 	 True 	 True
# True 	 True 	 True 	 True 	 False 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 False 	 False
# True 	 True 	 True 	 True 	 False 	 True 	 False 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 False
# True 	 True 	 True 	 True 	 False 	 False 	 True 	 True 	 True 	 True 	 True 	 True 	 True 	 False 	 False 	 True
# ...

# %% [markdown]
# The code first defines the conditional function in order to make it easy to evaluate particular premises as conditional is not a defined operation like "and", "not" and "or" in python. Then I defined the premises and used appropriate operations of "not" and "or" in order to evaluate each premise. Then I defined the conclusion. Finally I defined the main function that would evaluate the validity of the argument. First I created a variable for validity and set it to true, then we set up an iteration so that we could generate values for the truth table and then moved on to the actual printing of the truth table. Finally, I checked the truth table for validity via the rules that if each of the premise is true, the conclusion must also be true. The last if statement, checks this validity and if it gets a false output, changes the value of the validity variable and declares the argument to be invalid. If it does not get a false output, it simply declares ot to be valid. The last line is the calling of the deined function.

# %% [markdown]
# #### 3.2 *Optional challenge*: Write your own Python code that will create a truth table for any logical statement involving any number of atomic sentences and connectives. You can decide on the input/output format, but explain in detail what you are doing and why.

# %%
# write your code for 3.2 (optional) here

# %% [markdown]
# #### 3.3 *Optional super challenge*: Write your own Python code that will check the validity of any set of logical sentences that form an argument. Explain in detail how your code works. You can decide on the input/output format, but explain in detail what you are doing and why.

# %%
# write your code for 3.3 (optional) here

# %% [markdown]
# ### 4. For the fallacious argument (<200 words):
# #### 4.1 Name the type of fallacy or fallacies involved and justify the fallacious nature of the argument by explaining the flaw in logic.
# #### 4.2 Explain how the fallacy or fallacies could be corrected and the effect of the correction on the meaning of the conclusion and/or premises.
# #### (Translating this part of the argument into symbolic logic is not required but could be useful for your explanations.)

# %% [markdown]
# If I am rich, then I will have lots of money.
# If I have lots of money, then I can buy what I want.
# If I buy anything I want, I will be happy.
# I am happy
# I am successful
# Therefore, I would rather be rich rather than have political power.

# %% [markdown]
# It is a no sequitor of relevance of the form: If A then B. B. Therefore, C. This is a formal fallacy which makes the argument invalid as thre is a missing premise that relates B and C. In order to make it valid and remove the fallacy, we could add this premise: If I am happy, then I am successful. This is of the form, If B, then C. This would remove the fallacy and since we already have confirmation of A and C from the premises, we could conclude that it is now a valid argument with no fallacies.

# %% [markdown]
# ## PART 2
# #### For the other side of the argument, craft two brief arguments using inductive reasoning (please see the guidance provided above for how to construct your arguments from your question). One argument should be a strong induction and one should contain a fallacy. [#induction, #fallacies]

# %% [markdown]
# Would you rather have real political power but be relatively poor, or be ridiciously rich and have no political power?

# %% [markdown]
# Having political power means that I can have a say in the legislature of the country.
# It means I can make policies that suit my needs
# Political power means that I can make anything I want legal.
# It also means that I can control development projects.
# Development projects mean that the people will be happy.
# I want to make people happy.
# Being rich means that you have to pay taxes.
# Paying taxes is a time-demanding chore.
# So, it is probably better to have political power than to be rich.

# %% [markdown]
# The richest person in the world is Bill Gates.
# He says that money does not make you happy.
# Accroding to him, the poor are happy
# This means that all poor people are happy and all rich people are not happy.
# I want to be happy
# So, it is probably better to be poor, then happy
# I can be either rich or have political power.
# I do not want to be rich.
# So, I would choose political power.

# %% [markdown]
# ### 1. Clearly identify the features of these arguments that make them inductive and explain why (<75 words).

# %% [markdown]
# The premises are not necessarily true as a matter of logic and more as a matter of fact. The evidence is also based on the observations of a person and not proper logic rules. The terminoolgy used e.g. probably is also of an inductive nature. Moreover, this argument is of a predictive nature. All these factors combine to form an inductive argument.

# %% [markdown]
# ### 2. For the strong induction (<200 words):
# #### 2.1 Is this a specific type of induction? Which type, and why?
# #### 2.2 Elaborate on the strength and reliability of the argument. Explain how the argument could be made more reliable (including by increasing the strength).

# %% [markdown]
# It is a form of prediction as we are merely predicting the events that have not occured e.g. the people will be happy with the development projects and that I can make policies as per my choice. All of these are assumptions as the people might be happy and might not be happy with the development projects and it is not necessary that the policies can be agreed upon in the parliament. Some policies might face opposition and be rejected. The argument is of a strong nature as the conclusion follow from the premises and it could also be said to be reliable as the premises have a high-chance of being true. However, the reliability can be increased by adding in data that reflects as evdence to the argument e.g. how many tax-payers found it time consuming to be paying taxes and how many people in the general public are happy with development projects.

# %% [markdown]
# ### 3. For the fallacious argument (<200 words):
# #### 3.1 Name the type of fallacy or fallacies involved and justify the fallacious nature of the argument by explaining the flaw in logic.
# #### 3.2 Explain how the fallacy or fallacies could be corrected and the effect of the correction on the meaning of the conclusion and/or premises.

# %% [markdown]
# The richest person in the world is Bill Gates.
# He says that money does not make you happy.
# Accroding to him, the poor are happy
# This means that all poor people are happy and all rich people are not happy.
# I want to be happy
# So, it is probably better to be poor, then happy
# I can be either rich or have political power.
# I do not want to be rich.
# So, I would choose political power.

# %% [markdown]
# The fallacies present are "Inappropriate appeal to authority" and "hasty generalization." Taking Bill Gates words on happiness to be true is an Inappropriate appeal to authority as he is not an expert on human psychology and can't judge the happiness of the people. It is hasty generalization when we use Bill Gates alone to generalize that all rich people are not happy. There might be rich people who are happy. It is also a kind of "false dichotomy" as according to the argument, one can either be rich or have political power. This is not necessarily true as people might not have both. We could remove the first fallacy by using quotes from an expert on human psychology. As for the second, we could bring in more data and a much more random sample to make our generalization better. This argument is still strong but not reliable. Adding the mentioned data would make the conclusion reliable as well.

# %% [markdown]
# ## Reflection
#
# ### Reflect on what you learned in this assignment. Address the following points in <300 words total:  [#scienceoflearning, #selfawareness, and other HCs per use]
# #### 1. How did the principles from the science of learning deepen your knowledge of #induction, #deduction, #algorithms, and #fallacies while working on this assignment? (<100 words)
# #### 2. Throughout both sections, what did you learn about the connection between formal logic, language, computer code, and the use of logical thinking in the real world? (<100 words)
# #### 3. Describe how you obtained the knowledge to complete the assignment, being sure to include attributions to specific individuals or groups who helped you and how they helped. You should elaborate on any strategies you used to identify gaps and weaknesses in your own understanding of the material. (<100 words)

# %% [markdown]
# Write your reflection here, addressing points 1, 2, and 3.
#
# 1.  I used chunking that we learned from #scienceoflearning in order to understand the different forms of fallacies. I also made associations and used story telling in order to understand the fallacy examples well. A lot of self-explanation and note-taking was involved as well. Knowing these principles and their application in real life helped me a lot to deepen my understanding of the topics.
#
#
#
# 2.  I learned that language can be quite mis-leading and you can easily get distracted by common fallacies. In this situation, formal logic is the best way to judge an argument as it provides a clear path towards checking the validity and soundness of arguments without getting distracted. Formal logic is very similar to computer code as most programming languages have operations corresponding to functions of formal logic. It is very easy to communicate with the computer by using formal logic.
#
#
#
# 3.  When I started the assignment I read through all of it and divided it into three sections-deductive, inductive, and python. Then, I focused on the gaps in my knowledge such as limited knowledge of python and fallacies. As I was travelling during our class on fallacies, I knew I had to give it another reading. I looked through the readings again and made notes along with using self-explanation to cover these gaps in knowledge. I went through some code operations with my father who is a software engineer and then found it much easier to complete the assignment.

# %% [markdown]
# ### *Optional reflection questions*
# #### *Optional* 1: What side of the *would you rather* argument do believe was argued more effectively and why? (<200 words)

# %% [markdown]
# Write your explanation here for the first optional reflection question.

# %% [markdown]
# #### *Optional* 2: Create a new assignment problem for future classes that you think is a good test of the skills covered by one or more of these HCs. Provide the complete step-by-step solution, and a justification for why this is a good assignment problem. It should be entirely different from this assignment. *The FA team would like to thank Dima Lkhagvatogtokh (M22) for her submission to this question in 2018; her idea formed the basis for the assignment that you just completed!*

# %% [markdown]
# Write your explanation here for the second optional reflection question.

# %% [markdown]
# ## You're done!
#
# You must upload TWO files:
#
#
# 1. A **zipped folder** containing the .ipynb file and any other relevant files for running the notebook.
#
#
# 2. A **PDF** of your entire assignment. A PDF of your entire assignment. This is to be submitted as a separate file, NOT simply inside the zipped folder. Email attachments will not be accepted. We encourage students to follow the tips available in [this guide](https://docs.google.com/document/d/1gRMol9Ebbvyu1mvEKzma92o_N7ZbNXsPIb1QdQV0TeE/edit?usp=sharing), *especially the best practices listed at the end*.
